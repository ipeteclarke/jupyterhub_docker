# %%
import sqlalchemy
import pandas as pd

# %%
# !pip install psycopg2-binary

# %%
engine = sqlalchemy.create_engine('postgresql://postgres:107icsPaSS@postgres:5432/postgres')
inspector = sqlalchemy.inspect(engine)
# Get table information
print(inspector.get_table_names())
# Out:
# ['twin_properties', 'twin_feed_values']

# %%
sql = "select * from twin_feed_values"
df_tfv = pd.read_sql(sql,con=engine)

# %%
import pandas as pd
sql = "select * from twin_properties"
df_tp = pd.read_sql(sql,con=engine)

# %%
df_tfv
# Out:
#                            time  \
# 0    2023-12-02 00:41:54.727457
# 1    2023-12-02 00:41:54.727457
# 2    2023-12-02 00:41:54.727457
# 3    2023-12-02 00:41:56.235321
# 4    2023-12-02 00:41:56.235321
# ...                         ...
# 3778 2023-12-16 01:10:05.635359
# 3779 2023-12-16 01:10:05.635359
# 3780 2023-12-16 01:10:09.333407
# 3781 2023-12-16 01:10:09.333407
# 3782 2023-12-16 01:10:09.333407
#
#                                                   sym  \
# 0     did:iotics:iotLRHbwHV11EzaqaGnPhA4WaNxCvKcumfLS
# 1     did:iotics:iotLRHbwHV11EzaqaGnPhA4WaNxCvKcumfLS
# 2     did:iotics:iotLRHbwHV11EzaqaGnPhA4WaNxCvKcumfLS
# 3     did:iotics:iotKGFn6jij6xqaxcfEKx9kxXMEFiY7vcdRG
# 4     did:iotics:iotKGFn6jij6xqaxcfEKx9kxXMEFiY7vcdRG
# ...                                               ...
# 3778  did:iotics:iotGitNBZ2AfzzecrrQhsVecY9J8XvuXxWUg
# 3779  did:iotics:iotGitNBZ2AfzzecrrQhsVecY9J8XvuXxWUg
# 3780  did:iotics:iotUqtVnsTwoWPeC3tPDeDogiHjkpTuxfwQd
# ...

# %%
df_tp
# Out:
#                           time  \
# 0   2023-12-02 00:41:52.874911
# 1   2023-12-02 00:41:52.874911
# 2   2023-12-02 00:41:52.874911
# 3   2023-12-02 00:41:52.874911
# 4   2023-12-02 00:41:52.874911
# ..                         ...
# 523 2023-12-16 00:57:45.671296
# 524 2023-12-16 00:57:45.671296
# 525 2023-12-16 00:57:45.671296
# 526 2023-12-16 00:57:45.671296
# 527 2023-12-16 00:57:45.671296
#
#                                                  sym  \
# 0    did:iotics:iotGitNBZ2AfzzecrrQhsVecY9J8XvuXxWUg
# 1    did:iotics:iotGitNBZ2AfzzecrrQhsVecY9J8XvuXxWUg
# 2    did:iotics:iotGitNBZ2AfzzecrrQhsVecY9J8XvuXxWUg
# 3    did:iotics:iotGitNBZ2AfzzecrrQhsVecY9J8XvuXxWUg
# 4    did:iotics:iotGitNBZ2AfzzecrrQhsVecY9J8XvuXxWUg
# ..                                               ...
# 523  did:iotics:iotW4J2CSTNSK4QFBknQqT478VfSg1AfZuDX
# 524  did:iotics:iotW4J2CSTNSK4QFBknQqT478VfSg1AfZuDX
# 525  did:iotics:iotW4J2CSTNSK4QFBknQqT478VfSg1AfZuDX
# ...
